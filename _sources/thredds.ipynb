# %% [markdown]
# (sec:thredds)=
# # THREDDS data server
#
# The THREDDS (Thematic Real-time Environmental Distributed Data Services) data server is used to provide access to a catalogue of data hosted by [satellittdata.no](https://satellittdata.no). This catalogue is searchable via either a human or machine interface, to allow automated services to be built easily on top of it.
